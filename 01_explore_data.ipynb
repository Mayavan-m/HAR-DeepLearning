# %%
  import numpy as np
  import pandas as pd
  import matplotlib.pyplot as plt
  import seaborn as sns

# %%
path = 'UCI HAR Dataset/'

# %%
 X_train = pd.read_csv(path+'train/X_train.txt', sep=r'\s+', header=None)

# %%
 y_train = pd.read_csv(path+'train/y_train.txt', sep=r'\s+', header=None)

# %%
 subject_train = pd.read_csv(path+'train/subject_train.txt', sep=r'\s+',
  header=None)

# %%
 X_test = pd.read_csv(path+'test/X_test.txt', sep=r'\s+', header=None)

# %%
 y_test = pd.read_csv(path+'test/y_test.txt', sep=r'\s+', header=None)

# %%
subject_test = pd.read_csv(path+'test/subject_test.txt', sep=r'\s+',
  header=None)

# %%
print("Done!")
# Out:
# Done!

# %%
 print("X_train shape:", X_train.shape)
# Out:
# X_train shape: (7352, 561)

# %%
  print("y_train shape:", y_train.shape)
# Out:
# y_train shape: (7352, 1)

# %%
 print("X_test shape:", X_test.shape)
# Out:
# X_test shape: (2947, 561)

# %%
print("y_test shape:", y_test.shape)
# Out:
# y_test shape: (2947, 1)

# %%
activity_labels = pd.read_csv(path+'activity_labels.txt', sep=r'\s+',
header=None)                               
print(activity_labels)
# Out:
#    0                   1
# 0  1             WALKING
# 1  2    WALKING_UPSTAIRS
# 2  3  WALKING_DOWNSTAIRS
# 3  4             SITTING
# 4  5            STANDING
# 5  6              LAYING

# %%
print(y_train[0].value_counts().sort_index())
# Out:
# 0
# 1    1226
# 2    1073
# 3     986
# 4    1286
# 5    1374
# 6    1407
# Name: count, dtype: int64

# %%
activity_names =['WALKING','WALKING_UPSTAIRS','WALKING_DOWNSTAIRS','SITTING','STANDING','LAYING']
counts = y_train[0].value_counts().sort_index()
plt.figure(figsize=(10,5))
plt.bar(activity_names, counts)
plt.title('Number of recordings per activity')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.plot(X_train.iloc[0])
plt.title('Raw sensor data for one recording')
plt.xlabel('Sensor measurement number')
plt.ylabel('Value')
plt.show()
